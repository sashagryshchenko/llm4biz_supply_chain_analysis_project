# %%
# !pip install openai
# !pip install sentence-transformers
# !pip install langchain pypdf langchain-openai
# !pip install llama-index --upgrade
# Out:
# Collecting openai
#   Downloading openai-1.13.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.4-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 9.0 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.4 httpx-0.27.0 openai-1.13.3
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 45.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 72.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.5 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 67.8 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.5.1
# Collecting langchain
#   Downloading langchain-0.1.12-py3-none-any.whl (809 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 8.6 MB/s eta 0:00:00
# Collecting pypdf
#   Downloading pypdf-4.1.0-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 12.0 MB/s eta 0:00:00
# Collecting langchain-openai
#   Downloading langchain_openai-0.0.8-py3-none-any.whl (32 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.4-py3-none-any.whl (28 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting langchain-community<0.1,>=0.0.28 (from langchain)
#   Downloading langchain_community-0.0.28-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.7 MB/s eta 0:00:00
# Collecting langchain-core<0.2.0,>=0.1.31 (from langchain)
#   Downloading langchain_core-0.1.31-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.8/258.8 kB 15.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Downloading langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.24-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.6.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.2.3)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (1.13.3)
# Collecting tiktoken<1,>=0.5.2 (from langchain-openai)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: anyio<5,>=3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.2.0,>=0.1.31->langchain) (3.7.1)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.31->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.3 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.9.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.10.0->langchain-openai) (4.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.5.2->langchain-openai) (2023.12.25)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3->langchain-core<0.2.0,>=0.1.31->langchain) (1.2.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.10.0->langchain-openai) (0.14.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: pypdf, packaging, orjson, mypy-extensions, jsonpointer, typing-inspect, tiktoken, marshmallow, jsonpatch, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain-openai, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.12 langchain-community-0.0.28 langchain-core-0.1.31 langchain-openai-0.0.8 langchain-text-splitters-0.0.1 langsmith-0.1.24 marshmallow-3.21.1 mypy-extensions-1.0.0 orjson-3.9.15 packaging-23.2 pypdf-4.1.0 tiktoken-0.6.0 typing-inspect-0.9.0
# Collecting llama-index
#   Downloading llama_index-0.10.19-py3-none-any.whl (5.6 kB)
# Collecting llama-index-agent-openai<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.1.5-py3-none-any.whl (12 kB)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_cli-0.1.9-py3-none-any.whl (25 kB)
# Collecting llama-index-core<0.11.0,>=0.10.19 (from llama-index)
#   Downloading llama_index_core-0.10.19-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 43.4 MB/s eta 0:00:00
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.1.6-py3-none-any.whl (6.0 kB)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.1 MB/s eta 0:00:00
# Collecting llama-index-llms-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_llms_openai-0.1.9-py3-none-any.whl (10.0 kB)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.4-py3-none-any.whl (5.8 kB)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_program_openai-0.1.4-py3-none-any.whl (4.1 kB)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_readers_file-0.1.9-py3-none-any.whl (35 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.1.3-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (0.6.4)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.11.0,>=0.10.19->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.19->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (2023.6.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (0.27.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.13 (from llama-index-core<0.11.0,>=0.10.19->llama-index)
#   Downloading llamaindex_py_client-0.1.13-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (1.25.2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (1.13.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (1.5.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (9.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (4.10.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.19->llama-index) (0.9.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Collecting bs4<0.0.3,>=0.0.2 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting pymupdf<2.0.0,>=1.23.21 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading PyMuPDF-1.23.26-cp310-none-manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.1.0)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting llama-parse<0.4.0,>=0.3.3 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index)
#   Downloading llama_parse-0.3.9-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.19->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.19->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.19->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.14.1)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.19->llama-index) (2.6.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.19->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.19->llama-index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.0.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.19->llama-index) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.19->llama-index) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.19->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.19->llama-index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.7.0)
# Collecting PyMuPDFb==1.23.22 (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading PyMuPDFb-1.23.22-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 30.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.19->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.19->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.19->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.19->llama-index) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.19->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.19->llama-index) (2023.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.19->llama-index) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.19->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.19->llama-index) (2.16.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->llama-index-core<0.11.0,>=0.10.19->llama-index) (1.16.0)
# Installing collected packages: striprtf, dirtyjson, PyMuPDFb, deprecated, pymupdf, bs4, llamaindex-py-client, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed PyMuPDFb-1.23.22 bs4-0.0.2 deprecated-1.2.14 dirtyjson-1.0.8 llama-index-0.10.19 llama-index-agent-openai-0.1.5 llama-index-cli-0.1.9 llama-index-core-0.10.19 llama-index-embeddings-openai-0.1.6 llama-index-indices-managed-llama-cloud-0.1.4 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.9 llama-index-multi-modal-llms-openai-0.1.4 llama-index-program-openai-0.1.4 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.9 llama-index-readers-llama-parse-0.1.3 llama-parse-0.3.9 llamaindex-py-client-0.1.13 pymupdf-1.23.26 striprtf-0.0.26

# %%
import pandas as pd
from openai import OpenAI
from google.colab import userdata

# %%
open_ai_key = userdata.get('open_ai_key')
client = OpenAI(api_key=open_ai_key)

# %%
def gptrequest(prompt):
    response = client.chat.completions.create(
        model="gpt-4-turbo-preview",
        messages=[
            {"role": "system", "content": "You are an AI that takes instructions from a human and produces an answer. Be concise in your output."},
            {"role": "user", "content": prompt}
        ]
    )
    return response

# %%
prompt = "Summarize Supply Chain impacts of Fuel Cell Cars"
response = gptrequest(prompt)
print(response.choices[0].message.content)

prompt = "Summarize Supply Chain impacts of Electric cars"
response = gptrequest(prompt)
print(response.choices[0].message.content)
# Out:
# The adoption of fuel cell cars, which run on hydrogen and emit only water vapor, impacts the supply chain in multiple ways:
#
# 1. **Hydrogen Production and Distribution**: Requires establishing an entirely new supply chain for hydrogen production, storage, and distribution. This involves building infrastructure for hydrogen refueling stations and transportation solutions to move hydrogen safely.
#
# 2. **Sourcing of Raw Materials**: Increases demand for specific raw materials like platinum, used as a catalyst in fuel cells, potentially leading to supply constraints and price volatility for these critical inputs.
#
# 3. **Automotive Supply Chain**: Shifts in the automotive supply chain from traditional internal combustion engine components to those specific to fuel cell systems, such as fuel cell stacks and hydrogen tanks. This transition may pose challenges for current suppliers while creating opportunities for new entrants.
#
# 4. **Energy Sector Impact**: Promotes shifts in the energy sector towards green hydrogen production methods (e.g., electrolysis using renewable energy), impacting electricity demand and supply, renewable energy infrastructure, and potentially affecting the overall energy market dynamics.
#
# 5. **Environmental and Regulatory Influence**: Driven by stricter environmental regulations and government incentives for clean energy, the supply chain for fuel cell cars is also shaping and influenced by policy decisions at both national and international levels, affecting investments and the pace of infrastructure development.
#
# 6. **Global Supply Chain Networks**: Encourages the development of global supply chain networks and partnerships to facilitate the international standardization of hydrogen fueling interfaces and safety protocols, which is crucial for the widespread adoption of fuel cell vehicles.
#
# Overall, the transition to fuel cell cars introduces both challenges and opportunities, necessitating significant investments in new technologies, infrastructure, and global supply chain coordination to support its growth and sustainability.
# The shift towards electric cars impacts the supply chain in several significant ways:
#
# 1. **Battery Demand and Raw Materials**: The increased need for batteries amplifies demand for raw materials like lithium, cobalt, and nickel, leading to sourcing challenges and price volatility.
#
# 2. **Geographical Shifts**: As battery production is central to electric vehicle (EV) manufacturing, regions rich in essential minerals or with advanced battery manufacturing capabilities (e.g., Asia) gain strategic importance, potentially altering global trade dynamics.
#
# 3. **Supply Chain Resilience**: The concentration of critical mineral resources and battery production in specific regions raises concerns about supply chain resilience, including vulnerability to political instability and trade disputes.
#
# 4. **Infrastructure Development**: The rise of electric cars necessitates the expansion of charging infrastructure, impacting supply chains related to energy generation, storage, and distribution systems.
#
# 5. **Automotive Supply Chain Transformation**: Traditional automotive supply chains, heavily reliant on internal combustion engine components, need to adapt to accommodate EV-specific parts, such as electric motors and battery systems.
#
# 6. **Environmental and Regulatory Compliance**: The increasing focus on lower carbon footprints and sustainable supply chains pressures companies to ensure environmentally responsible sourcing of materials and to comply with evolving regulations related to emissions and battery recycling.
#
# 7. **Investment and R&D**: There's a surge in investment towards research and development to improve battery technology, reduce costs, and explore alternative materials, driving innovation across the supply chain.
#
# In summary, the rise of electric cars is reshaping supply chains through increased demand for specific raw materials, geographical shifts in production, challenges to resilience, infrastructure needs, and a push towards sustainability and innovation.

# %%
prompt = "create a table of a comparison between supply chain impacts of fuel cell cars vs electric vehicles"
response = gptrequest(prompt)
print(response.choices[0].message.content)

prompt = "create a table of a comparison between environmental impacts of fuel cell cars vs electric vehicles"
response = gptrequest(prompt)
print(response.choices[0].message.content)

prompt = "create a table of a comparison between Manufacturing Process of fuel cell cars vs electric vehicles"
response = gptrequest(prompt)
print(response.choices[0].message.content)
# Out:
# | Criteria | Fuel Cell Cars (Hydrogen) | Electric Vehicles (Battery EVs) |
# |----------|----------------------------|--------------------------------|
# | **Raw Material Extraction** | Relies mainly on extracting and processing hydrogen, often from natural gas or water via electrolysis, which can have significant energy requirements. | Requires extraction of various minerals (e.g., lithium, nickel, cobalt) for batteries, leading to considerable environmental impacts related to mining.|
# | **Manufacturing** | Production of fuel cells is energy-intensive, involving complex processes for creating the membrane and catalysts. | The manufacturing process, particularly for batteries, is energy and resource-intensive, contributing to higher environmental impacts.
# | **Energy Source Dependence** | Efficient when hydrogen is produced using renewable energy, but currently, most hydrogen is derived from fossil fuels, which offsets some environmental benefits. | EV efficiency and green impact largely depend on the cleanliness of the electricity grid they are charged from. More beneficial in regions with renewable energy sources.
# | **Infrastructure** | Requires development of a new hydrogen fueling infrastructure, which is costly and currently less developed than electrical charging networks. Limited availability restricts widespread adoption. | Benefits from a rapidly growing global charging infrastructure. Compatibility with existing electrical grids allows for easier integration but requires upgrades for widespread fast charging.
# | **Vehicle Emissions** | Zero emissions at the point of use. Water vapor is the only exhaust product. | Zero tailpipe emissions. However, the overall environmental impact depends on the electricity generation mix (e.g., coal, solar, wind).
# | **Energy Efficiency** | Generally lower efficiency due to the energy required to produce, compress, store, and convert hydrogen back to electricity. | Higher energy efficiency as electric motors convert more of the battery's electrical energy into drive energy.
# | **Lifecycle CO2 Emissions** | Potentially low if hydrogen is produced from renewable energy sources but currently higher due to reliance on fossil fuels for hydrogen production. | Emissions vary widely based on the source of electricity for charging and the environmental impact of battery production and disposal.
# | **Economic Aspects** | High costs associated with fuel cell technology and hydrogen infrastructure development hinder widespread adoption. | Generally lower operating costs than fuel cell vehicles, but the high initial purchase price and battery replacement costs are considerations. Economies of scale are improving affordability over time.
# | **Technology Maturity and Availability** | Less developed with fewer models available. Technology and infrastructure are still in early stages of public and commercial adoption. | More mature technology with a wide range of models available. EV technology is rapidly advancing, supported by significant investments and incentives.
# | Criteria                     | Fuel Cell Vehicles (FCVs)                                                                       | Electric Vehicles (EVs)                                                                     |
# |------------------------------|-------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------|
# | **Energy Source**            | Hydrogen (often produced from natural gas, water via electrolysis, or other chemical processes) | Electricity (sourced from the grid, which may include fossil fuels, nuclear, or renewables) |
# | **CO2 Emissions**            | Low to zero at point of use; depends on hydrogen production method                             | Zero at point of use; overall depends on electricity grid's energy mix                      |
# | **Energy Efficiency**        | Lower than EVs due to energy losses in hydrogen production, storage, and conversion            | Higher, as electric energy is directly used to power the vehicle                            |
# | **Fuel Production Impact**   | Can be high, especially if produced from natural gas or using energy-intensive processes       | Varies widely; can be low if powered by renewables, higher with coal or gas                  |
# | **Vehicle Range**            | Generally higher than most EVs, making them suitable for longer trips                          | Improving rapidly but varies; some models now match or surpass FCVs in range                |
# | **Refueling Infrastructure** | Less developed; requires investment in hydrogen fueling stations                               | More established with increasing availability of charging stations                           |
# | **Vehicle Cost**             | Currently, generally higher due to complex technology and lack of scale                       | Decreasing as technology matures and production scales up                                    |
# | **Maintenance**              | Low; fewer moving parts than internal combustion engines, but hydrogen systems are complex    | Low; fewer moving parts than conventional cars, generally simpler than FCVs                  |
# | Feature                                        | Fuel Cell Vehicles (FCVs)                  | Electric Vehicles (EVs)                    |
# |------------------------------------------------|--------------------------------------------|--------------------------------------------|
# | **Energy Source**                              | Hydrogen fuel cells                        | Lithium-ion batteries or other battery types |
# | **Primary Manufacturing Process for Energy Source** | Producing and shaping catalyst-coated membranes; assembling the fuel cell stacks | Mining and processing raw materials for batteries; manufacturing battery cells and packs |
# | **Fuel/Power Production**                      | Hydrogen gas is converted into electricity through a chemical process in fuel cells | Electricity stored in batteries is used to power an electric motor |
# | **Emissions**                                  | Water vapor                                | None (at the vehicle level)                |
# | **Infrastructure Required**                    | Hydrogen fueling stations                  | Electric charging stations                 |
# | **Vehicle Efficiency**                         | Higher efficiency compared to conventional ICE vehicles, but lower than EVs due to energy conversion losses | Higher efficiency due to direct energy conversion from electricity to power |
# | **Energy Storage**                             | Hydrogen is stored in high-pressure tanks within the vehicle | Electricity is stored in rechargeable batteries |
# | **Manufacturing Complexity**                   | High due to the complexity of fuel cell systems and hydrogen storage requirements | Moderately high, primarily due to the complexity of battery technology and management systems |
# | **Raw Material Utilization**                   | Platinum, carbon, and other materials for fuel cells and tanks | Lithium, cobalt, nickel, and other materials for batteries |
# | **Recycling and Sustainability**               | Challenges in recycling fuel cell components but potential for hydrogen to be produced from renewable sources | Battery recycling is challenging but improving; move towards more sustainable battery materials is underway |
# | **Cost Factors**                               | High initial cost for vehicle and infrastructure development; cost of hydrogen fuel | High initial cost mainly due to battery; cost decreasing with advancements in battery technology |
# | **Range and Refueling/Charging Time**          | Comparable to conventional vehicles; refueling takes minutes | Varies widely; recharging can take from 30 minutes (fast charging) to several hours |

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for supply chain comparison
criteria = ['Energy Source', 'Efficiency', 'Refueling Infrastructure', 'Emissions',
            'Supply Chain Complexity', 'Resource Use', 'Energy Storage',
            'Vehicle Range', 'Costs']
fuel_cell_scores = [3, 2, 2, 3, 3, 2, 3, 3, 2]  # Example scores for fuel cell cars
electric_vehicle_scores = [4, 5, 5, 4, 4, 5, 4, 4, 5]  # Example scores for electric vehicles

# Plotting the comparison
bar_width = 0.35
index = np.arange(len(criteria))

plt.figure(figsize=(10, 6))
plt.barh(index, fuel_cell_scores, bar_width, color='blue', label='Fuel Cell Cars')
plt.barh(index + bar_width, electric_vehicle_scores, bar_width, color='orange', label='Electric Vehicles')
plt.xlabel('Score')
plt.yticks(index + bar_width / 2, criteria)
plt.title('Supply Chain Comparison: Fuel Cell Cars vs Electric Vehicles')
plt.legend()
plt.show()

# %%
import numpy as np

# Data for supply chain comparison
criteria = ['Energy Source', 'Efficiency', 'Refueling Infrastructure', 'Emissions',
            'Supply Chain Complexity', 'Resource Use', 'Energy Storage',
            'Vehicle Range', 'Costs']
fuel_cell_scores = [3, 2, 2, 3, 3, 2, 3, 3, 2]  # Example scores for fuel cell cars
electric_vehicle_scores = [4, 5, 5, 4, 4, 5, 4, 4, 5]  # Example scores for electric vehicles

# Data for environmental impact comparison
factors = ['Greenhouse Gas Emissions', 'Air Pollution', 'Energy Efficiency', 'Resource Use',
           'Infrastructure', 'Vehicle Range and Refueling', 'Cost', 'Water Emission', 'Lifecycle Analysis']
fuel_cell_scores_env = [3, 3, 2, 2, 2, 3, 2, 3, 2]  # Example scores for fuel cell cars
electric_vehicle_scores_env = [4, 4, 5, 4, 5, 4, 5, 4, 5]  # Example scores for electric vehicles

# Plotting the comparison
bar_width = 0.35
plt.figure(figsize=(12, 8))

# Supply chain comparison
plt.barh(np.arange(len(criteria)) - bar_width/2, fuel_cell_scores, bar_width, color='blue', label='Fuel Cell Cars')
plt.barh(np.arange(len(criteria)) + bar_width/2, electric_vehicle_scores, bar_width, color='orange', label='Electric Vehicles', alpha=0.6)

# Environmental impact comparison
plt.barh(np.arange(len(factors)) - bar_width/2, fuel_cell_scores_env, bar_width, color='green', label='Fuel Cell Cars (Env)')
plt.barh(np.arange(len(factors)) + bar_width/2, electric_vehicle_scores_env, bar_width, color='red', label='Electric Vehicles (Env)', alpha=0.6)

plt.xlabel('Score')
plt.yticks(np.arange(len(criteria)), criteria)
plt.title('Supply Chain and Environmental Impact Comparison: Fuel Cell Cars vs Electric Vehicles')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Data for supply chain element comparison
features = ['Energy Source', 'Manufacturing of Energy Source', 'Vehicle Powertrain and Motor',
            'Manufacturing of Storage System', 'Energy Conversion and Efficiency',
            'Infrastructure for Refueling/Charging', 'Environmental Impact of Manufacturing',
            'Vehicle Lifespan and Maintenance']
fuel_cell_scores = [3, 3, 2, 2, 3, 2, 3, 2]  # Example scores for fuel cell cars
electric_vehicle_scores = [4, 4, 5, 4, 5, 4, 5, 4]  # Example scores for electric vehicles

# Plotting the comparison
bar_width = 0.35
plt.figure(figsize=(12, 8))

plt.barh(np.arange(len(features)) - bar_width/2, fuel_cell_scores, bar_width, color='purple', label='Fuel Cell Cars')
plt.barh(np.arange(len(features)) + bar_width/2, electric_vehicle_scores, bar_width, color='yellow', label='Electric Vehicles', alpha=0.6)

plt.xlabel('Score')
plt.yticks(np.arange(len(features)), features)
plt.title('Supply Chain Element Comparison: Fuel Cell Cars vs Electric Vehicles')
plt.legend()
plt.tight_layout()
plt.show()
