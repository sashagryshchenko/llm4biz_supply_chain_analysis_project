# %%
# %pip install pathlib
# %pip install ruamel-yaml
# Out:
# ...
#      |████████████████████████████████| 117 kB 7.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 148 kB 46.3 MB/s eta 0:00:01
# ...

# %%
# %pip install openai
# %pip install sentence-transformers
# %pip install langchain pypdf langchain-openai #tiktoken chromadb
# %pip install llama-index --upgrade
# Out:
# ...
#   Using cached openai-1.13.3-py3-none-any.whl (227 kB)
# ...
#   Using cached tqdm-4.66.2-py3-none-any.whl (78 kB)
# ...
#   Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# ...
#   Using cached httpcore-1.0.4-py3-none-any.whl (77 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
# ...
#      |████████████████████████████████| 3.3 MB 8.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.4 MB 185.0 MB/s eta 0:00:01
# ...
#   Using cached transformers-4.38.2-py3-none-any.whl (8.5 MB)
# ...
#   Using cached huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
# ...
#      |████████████████████████████████| 31.4 MB 18.5 MB/s eta 0:00:01
# ...

# %%
import langchain

# %%
from langchain.chains.summarize import load_summarize_chain
from langchain.chains.combine_documents.stuff import StuffDocumentsChain
from langchain.chains.llm import LLMChain
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
import pandas as pd
import numpy as np

# %%
import config

# %%
# Import necessary classes from the llama_index package
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, SummaryIndex
from llama_index.core import Settings
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from openai import OpenAI
# from google.colab import userdata
import os

open_ai_key = config.api_key
# userdata.get('ai_key')

client = OpenAI(api_key=open_ai_key)
os.iron["OPENAI_API_KEY"] = open_ai_key
client = OpenAI(api_key=open_ai_key)
import textwrap

# %%
def gptrequest(prompt):
  response = client.chat.completions.create(
        model="gpt-4-turbo-preview",
        messages=[
            {"role": "system", "content": "You are an AI that takes instructions from a human and produces an answer. Be concise in your output."},
            {"role": "user", "content": prompt}
        ]

  )
  return response

# %%
def list_of_papers_by_subject(subject):
    return f"Return a list, in a bullet point format enclosed within backticks, of top 5 most relevant papers and the author(s) name(s) on the research related to the production of {subject} and materials needed."

# %%
subjects = ['fuel cell cars', 'electric cars', 'autonomous fuel']

# %%
for subject in subjects:
    prompt = list_of_papers_by_subject(subject)
    print("subject: " + subject)
    response = gptrequest(prompt)
    table_out = response.choices[0].message.content
    print(table_out)
# Out:
# subject: fuel cell cars
# I'm unable to provide real-time or the most current research data, including specific details about recent papers, authors, or their publications due to my last training data up until 2023. However, I can suggest some historically influential papers and researchers in the field of fuel cell cars and the materials needed for them, based on prior knowledge up to that point. For the most current information, please consult a specific academic database like Google Scholar, Web of Science, or Scopus.
#
# ```
# - "The Role of Nanotechnology in the Development of Battery Materials for Electric Vehicles" by Daniel J. L. Brett, Paul R. Shearing, Nigel P. Brandon (Year: Not Specified): A review of the advances in nanotechnology for battery materials, relevant due to the crossover between electric vehicle battery technology and fuel cell technology.
#
# ...
